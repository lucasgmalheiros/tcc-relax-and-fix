# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../solve_gurobi/resultados_n_plantas_produto.csv')

# %%
df = df[['Plantas', 'Lower Bound (LB)', 'Upper Bound (UB)']]

# %%
df.loc[df['Lower Bound (LB)'] == 'inf', 'Lower Bound (LB)'] = None
df.loc[df['Upper Bound (UB)'] == 'inf', 'Upper Bound (LB)'] = None

# %%
x = df['Plantas']
y1 = df['Lower Bound (LB)']
y2 = df['Upper Bound (UB)']

# %%
plt.scatter(x[:11], y1[:11])
